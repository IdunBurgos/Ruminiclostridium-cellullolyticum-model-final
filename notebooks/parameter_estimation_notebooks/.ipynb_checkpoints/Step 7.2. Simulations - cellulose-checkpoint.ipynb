# %% [markdown]
# ### Optimizing parameters for cellulose growth

# %% [markdown]
# Data:
# - Cellulose concentration
# - Biomass concentration
# - Cellodextrin concentration: glc,cellb, and cell3
# - Acetate,lactate,ethanol concentration
#
#
# Parameters:
# -

# %%
import pandas as pd

# %%
import numpy as np
from tqdm import tqdm

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline

from collections import OrderedDict

# %%
import cobra
from cobra.io import load_model

import pandas as pd
import copy
import numpy as np

import molmass
import reframed

from scipy.interpolate import interp1d
from sklearn.metrics import r2_score

from scipy.optimize import minimize
from sklearn.metrics import mean_squared_error
from optimparallel import minimize_parallel
from scipy.optimize import differential_evolution

import matplotlib.colors as mcolors

import sys
sys.path.append("../functions/")

# %load_ext autoreload
# %autoreload 2

from dfba_param_opt_cobra_cellulose import read_model,optimize_parameters_inner_problem_cellulose

from differential_evolution_process_results import process_results

# %%
cellulose_exp = pd.read_csv("../input/Desvaux2001_batch_data/cellulose_g.csv")
molar_mass = 180.156  
cellulose_exp["y mmol"]= cellulose_exp[" y"].map(lambda x: (x/molar_mass)*1000)

biomass_exp = pd.read_csv("../input/Desvaux2001_batch_data/biomass_mg.csv")
biomass_exp["y g"] = biomass_exp[" y"].map(lambda x: x/1000)

cellb_exp = pd.read_csv("../input/Desvaux2001_batch_data/cellobiose_mmol.csv")
glc_exp = pd.read_csv("../input/Desvaux2001_batch_data/glucose_mmol.csv")

acetate_exp = pd.read_csv("../input/Desvaux2001_batch_data/acetate_mmol.csv")
ethanol_exp = pd.read_csv("../input/Desvaux2001_batch_data/ethanol_mmol.csv")
lactate_exp = pd.read_csv("../input/Desvaux2001_batch_data/lactate_mmol.csv")

# %%
interp_func = interp1d(acetate_exp.x,acetate_exp[" y"], kind='linear', fill_value="extrapolate")
y_interp = interp_func(ethanol_exp.x.values)

ratio1 = y_interp.sum()/ethanol_exp[" y"].sum()

# %%
y_interp = interp_func(lactate_exp.x.values)
y_interp  

ratio2 = y_interp.sum()/lactate_exp[" y"].sum()

# %%
RcH10_final2 = reframed.load_cbmodel("../models/RcH10_final.xml")

#RcH10_final2.reactions.R_H2td.reversible=False
#RcH10_final2.reactions.R_H2td.lb=0
#RcH10_final2.add_reaction_from_str("R_H2td_2: M_h2_c --> M_h2_e")

RcH10_final2.add_ratio_constraint("R_EX_ac_e","R_EX_etoh_e",round(ratio1,2))
#RcH10_final2.add_ratio_constraint("R_H2td","R_EX_cellb_e",-4)
#RcH10_final2.add_ratio_constraint("R_H2td_2","R_EX_glc__D_e",-2)
RcH10_final2.add_ratio_constraint("R_EX_ac_e","R_EX_lac__L_e",round(ratio2,2))
reframed.save_cbmodel(RcH10_final2,"../models/RcH10_final_flux_ratio.xml")

# %% [markdown]
# ### Additional functions

# %%
from concurrent.futures import ProcessPoolExecutor

# Initialize any shared variables if needed
pop_min = []
energies_min = []

def maplike_fun(func, x, *args, max_workers=4):
    # Store the current population
    print(x)
    pop_min.append(np.copy(x))

    # Evaluate the objective function for each individual in parallel
    e = []
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        # Submit each individual to the executor, running them in parallel
        futures = [executor.submit(func, x_i, *args) for x_i in x]
        
        # Collect the results as they complete
        for future in futures:
            e.append(future.result())
    
    # Store the energies (objective function values)
    energies_min.append(e)
    
    # Return the objective values, ensuring it matches the length of x
    return e

# %% [markdown]
# ### Optimize parameters

# %%
glc_eq_dict =OrderedDict({
"EX_glc__D_e": 1,
"EX_cellb_e":2})

C_dict =OrderedDict({
"Growth":biomass_exp.loc[0,"y g"],
"EX_glc__D_e": 0,
"EX_cellb_e": 0,
"EX_ac_e":0,
"EX_etoh_e":0,
"EX_lac__L_e":0
})


C_dict["EX_cellulose_e"]= cellulose_exp.loc[0,"y mmol"]


rxns = list(C_dict.keys())
y0 = np.array(list(C_dict.values()))

objective_dir = ["max", "max","max","max","max","max"]
best_r2 = {}

media = pd.read_csv('../input/media_db.tsv',sep='\t')
media = media.groupby('medium').agg({'compound': set})['compound'].to_dict()

# %%
# %%time
model = read_model(media)

pop_min = []
energies_min = []
res_min = differential_evolution(optimize_parameters_inner_problem_cellulose,
                  bounds=[(0.1,10),(0.1,20),(0.1,10),(0.1,20),(0.1,10),(0.1,20),(0.1,20)],
                  args=(model,media,rxns,y0,objective_dir,glc_eq_dict),
                  strategy = "rand2bin",
                  workers=maplike_fun,
                  mutation = (0.6,0.8),
                  recombination=0.7,
                  popsize=5,
                  maxiter=25,
                  polish=False,
                  seed=1,
                  updating='deferred')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-14
# [[ 3.57063675  7.43223245  5.22655188  0.90691345  7.27610953 10.25470161
#   18.18596756]
#  [ 1.60353156 14.06914696  3.94074449 17.22897021  0.14151095  1.3497777
#   19.20029371]
#  [ 8.48432873 19.31692033  1.14439983 19.93909958  3.68194488 13.9618517
#   11.32764916]
#  [ 2.11677951 14.69479242  6.37813577  8.35967018  8.4583007  13.21695545
#    2.76766727]
#  [ 0.21795765  8.63756694  5.774091    3.76608803  7.95555893  6.78125013
#    1.16784391]
#  [ 4.519179   13.52963197  5.54018415  4.2003257   2.79135435 15.96758673
#    6.31306916]
#  [ 1.87646844 11.54901311  4.6057551  13.26628996  9.39036774 16.3364971
#   17.11093701]
#  [ 0.48060146 19.8904707   1.25924668 16.9321651   8.62392239 19.53605151
#   12.15558672]
#  [ 9.83981131 10.81304042  1.82634107  5.59455753  7.0525565  17.11517173
#    5.04338752]
#  [ 7.06007605  0.89416208  7.24636296 17.82589444  8.2887641  11.39384237
#    8.57656713]
#  [ 9.58882381  9.77701756  9.31605544  2.95325533  9.8805939   8.72655932
#    9.60169551]
#  [ 6.39422928 13.03148956  1.75036555  6.85650832  6.6109687  11.53254666
#    8.7065429 ]
#  [ 9.13671157  1.98391832  8.19446016 12.08092252  8.96249798  7.27633557
#    0.20590223]
#  [ 7.9987314  11.35807401  2.79729641 11.54042099  2.39180317 12.36300569
#    4.11034042]
#  [ 8.0239463   4.0910115   4.91598539  9.78180855  6.59723423  4.88399183
#   13.45366479]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmp9cmjyn4g.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# [ 2.52525041  0.50955593  3.61537437  9.02139568  1.72646939 17.44464792
#  14.43378465]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpdrnuairx.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 602.6075290420933
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmp8h9wpp0b.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 586.2834694556727
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmprqmcck5t.lp
# Reading time = 0.02 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 648.8608302426366
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmp5wavjmce.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 2576.011312813532
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpst5_078s.lp
# Reading time = 0.02 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# [ 9.2489398   3.96019025  9.8063121  19.14160129  4.97821399 14.6723251
#   1.69242334]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpsog5n92s.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# [ 4.06081189 18.19598851  0.10003235  0.27189766  4.83895355  5.87972996
#  10.07207823]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmp8hou9azl.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# [ 4.04571268 16.81031867  0.78375193 15.34041759  9.60374834  3.67836919
#  15.18116969]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpnlm7p1k7.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# [ 1.27946632 15.60113159  8.87281965  1.55479793  2.05414559  4.35949445
#  14.0589677 ]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpvkyixeee.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 748.5031275421644
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpzj0jo6jt.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# [ 6.24167403  7.74723576  6.84019745 18.79396447  5.35711477  8.26313338
#  10.65327147]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpke4i6il8.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 709.4760120316204
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpvol3yxz4.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# penalty: 626.9922859302636
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmptqwb7vvi.lp
# Reading time = 0.02 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# [ 0.67346106  5.24554497  6.97833965  2.30400412  4.31059505 10.88557015
#   3.67504941]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmp4giv_4xi.lp
# Reading time = 0.03 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# had issues with this combination: [ 1.27946632 15.60113159  8.87281965  1.55479793  2.05414559  4.35949445
#  14.0589677 ], the ratio_R_EX_ac_e_R_EX_etoh_e is:-1.17 and the ratio_R_EX_ac_e_R_EX_lac__L_e is -4.69
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmp9y995h8l.lp
# Reading time = 0.03 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# Process SpawnProcess-5:
# Traceback (most recent call last):
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/assumptions.py", line 499, in getit
#     return self._assumptions[fact]
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/multiprocessing/queues.py", line 116, in get
#     return _ForkingPickler.loads(res)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/optlang/gurobi_interface.py", line 615, in __setstate__
#     self.__init__(problem=problem)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/optlang/interface.py", line 1178, in __init__
#     self._initialize_model_from_problem(problem)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/optlang/gurobi_interface.py", line 552, in _initialize_model_from_problem
#     [symbolics.Real(row.getCoeff(i)) * self.variables[row.getVar(i).VarName] for i in
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/optlang/gurobi_interface.py", line 552, in <listcomp>
#     [symbolics.Real(row.getCoeff(i)) * self.variables[row.getVar(i).VarName] for i in
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/decorators.py", line 65, in __sympifyit_wrapper
#     return func(a, b)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/numbers.py", line 1036, in __mul__
#     return Number.__mul__(self, other)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/decorators.py", line 65, in __sympifyit_wrapper
#     return func(a, b)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/numbers.py", line 485, in __mul__
#     return AtomicExpr.__mul__(self, other)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/decorators.py", line 236, in _func
#     return func(self, other)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/decorators.py", line 106, in binary_op_wrapper
#     return func(self, other)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/expr.py", line 219, in __mul__
#     return Mul(self, other)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/operations.py", line 98, in __new__
#     c_part, nc_part, order_symbols = cls.flatten(args)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/mul.py", line 685, in flatten
#     elif coeff.is_zero:
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/assumptions.py", line 502, in getit
#     self._assumptions = self.default_assumptions.copy()
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/assumptions.py", line 482, in copy
#     return self.__class__(self)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/assumptions.py", line 479, in __init__
#     self.deduce_all_facts(facts)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/sympy/core/facts.py", line 619, in deduce_all_facts
#     for k, v in facts:
# KeyboardInterrupt
# had issues with this combination: [ 4.04571268 16.81031867  0.78375193 15.34041759  9.60374834  3.67836919
#  15.18116969], the ratio_R_EX_ac_e_R_EX_etoh_e is:-1.17 and the ratio_R_EX_ac_e_R_EX_lac__L_e is -4.69
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmprt2utoe8.lp
# Reading time = 0.02 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# had issues with this combination: [ 9.2489398   3.96019025  9.8063121  19.14160129  4.97821399 14.6723251
#   1.69242334], the ratio_R_EX_ac_e_R_EX_etoh_e is:-1.17 and the ratio_R_EX_ac_e_R_EX_lac__L_e is -4.69
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpq7rpqwdp.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# had issues with this combination: [ 6.24167403  7.74723576  6.84019745 18.79396447  5.35711477  8.26313338
#  10.65327147], the ratio_R_EX_ac_e_R_EX_etoh_e is:-1.17 and the ratio_R_EX_ac_e_R_EX_lac__L_e is -4.69
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpk_gotc_5.lp
# Reading time = 0.02 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/concurrent/futures/process.py", line 239, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/Users/idunmariaburgos/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/optimize/_differentialevolution.py", line 1346, in __call__
#     return self.f(x, *self.args)
#   File "../functions/dfba_param_opt_cobra_cellulose.py", line 144, in optimize_parameters_inner_problem_cellulose
#     C_dict_results = dict(zip(rxns,sol.y))
# UnboundLocalError: local variable 'sol' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 20, in maplike_fun(func, x, max_workers, *args)
#      19     for future in futures:
# ---> 20         e.append(future.result())
#      22 # Store the energies (objective function values)
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     440 else:
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/concurrent/futures/_base.py:388, in Future.__get_result(self)
#     387 if self._exception:
# --> 388     raise self._exception
#     389 else:
#
# UnboundLocalError: local variable 'sol' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/optimize/_differentialevolution.py:329, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0)
#     314 # using a context manager means that any created Pool objects are
#     315 # cleared up.
#     316 with DifferentialEvolutionSolver(func, bounds, args=args,
#     317                                  strategy=strategy,
#     318                                  maxiter=maxiter,
#    (...)
#     327                                  constraints=constraints,
#     328                                  x0=x0) as solver:
# --> 329     ret = solver.solve()
#     331 return ret
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/optimize/_differentialevolution.py:843, in DifferentialEvolutionSolver.solve(self)
#     838     self.feasible, self.constraint_violation = (
#     839         self._calculate_population_feasibilities(self.population))
#     841     # only work out population energies for feasible solutions
#     842     self.population_energies[self.feasible] = (
# --> 843         self._calculate_population_energies(
#     844             self.population[self.feasible]))
#     846     self._promote_lowest_energy()
#     848 # do the optimization.
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/optimize/_differentialevolution.py:966, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#     964 parameters_pop = self._scale_parameters(population)
#     965 try:
# --> 966     calc_energies = list(self._mapwrapper(self.func,
#     967                                           parameters_pop[0:nfevs]))
#     968     energies[0:nfevs] = np.squeeze(calc_energies)
#     969 except (TypeError, ValueError) as e:
#     970     # wrong number of arguments for _mapwrapper
#     971     # or wrong length returned from the mapper
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/_lib/_util.py:471, in MapWrapper.__call__(self, func, iterable)
#     468 def __call__(self, func, iterable):
#     469     # only accept one iterable because that's all Pool.map accepts
#     470     try:
# --> 471         return self._mapfunc(func, iterable)
#     472     except TypeError as e:
#     473         # wrong number of arguments
#     474         raise TypeError("The map-like callable must be of the"
#     475                         " form f(func, iterable)") from e
#
# Cell In[8], line 20, in maplike_fun(func, x, max_workers, *args)
#      18     # Collect the results as they complete
#      19     for future in futures:
# ---> 20         e.append(future.result())
#      22 # Store the energies (objective function values)
#      23 energies_min.append(e)
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/concurrent/futures/_base.py:636, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     635 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636     self.shutdown(wait=True)
#     637     return False
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/concurrent/futures/process.py:686, in ProcessPoolExecutor.shutdown(self, wait)
#     684     self._queue_management_thread_wakeup.wakeup()
#     685     if wait:
# --> 686         self._queue_management_thread.join()
#     687 # To reduce the risk of opening too many files, remove references to
#     688 # objects that use file descriptors.
#     689 self._queue_management_thread = None
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/threading.py:1011, in Thread.join(self, timeout)
#    1008     raise RuntimeError("cannot join current thread")
#    1010 if timeout is None:
# -> 1011     self._wait_for_tstate_lock()
#    1012 else:
#    1013     # the behavior of a negative timeout isn't documented, but
#    1014     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1015     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/threading.py:1027, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1025 if lock is None:  # already determined that the C code is done
#    1026     assert self._is_stopped
# -> 1027 elif lock.acquire(block, timeout):
#    1028     lock.release()
#    1029     self._stop()
#
# KeyboardInterrupt:

# %%
# %%time

combination = [ 3.63596667,18.4505937,5.99508178,  5.84648022,
   9.28404018,  16.4277976,  7.85250370,  0.349110473,
   0.235408538]

model = read_model(media)
result = minimize_parallel(optimize_parameters_inner_problem_cellulose,
                  combination,
                  bounds=[(0.1,10),(0.1,20),(0.1,10),(0.1,20),(0.1,10),(0.1,20),(0.1,20),(0,0.5),(-2,2)],
                  args=(model,media,rxns,y0,objective_dir,glc_eq_dict),
                 options ={'maxiter':100,'gtol': 1e-3,'ftol':1e-4},
                  parallel = {'max_workers':4,'verbose':False})

# %% [markdown]
# CPU times: user 16.7 s, sys: 2.97 s, total: 19.7 s
# Wall time: 42min 46s

# %%
pd.Series({"result.x":[ 5.16907737,  1.77849702,  6.04687408,  1.76492112,  5.59893772,
        8.81471336, 10.6161635 ,  0.07552199,  0.24068677],
"result.success":True,
"results.message":"CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH",
"result.fun":84.2600877155809
})
# Out:
# result.x           [5.16907737, 1.77849702, 6.04687408, 1.7649211...
# result.success                                                  True
# results.message      CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# result.fun                                                 84.260088
# dtype: object

# %%
# %%time
combination =  [ 3.57063675,7.43223245,5.22655188,0.90691345,7.27610953,10.25470161,
 18.18596756]
model = read_model(media)
sol,penalty,penalty_dict = optimize_parameters_inner_problem_cellulose(combination=combination,model=model,media=media,rxns=rxns,y0=y0,objective_dir=objective_dir,glc_eq_dict=glc_eq_dict,alternative_solution=True,t_end=150)
# Out:
# [3.57063675, 7.43223245, 5.22655188, 0.90691345, 7.27610953, 10.25470161, 18.18596756]
# Read LP format model from file /var/folders/mc/1rm74nkd4s78l46281nyt5wm0000gn/T/tmpphy7bs2y.lp
# Reading time = 0.01 seconds
# : 1067 rows, 5248 columns, 15982 nonzeros
# t:-0.1962906717502988
# y:[1.95875438e-02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.71321900e+01]
# fluxes:[ 0.          0.0558395   0.02791975  0.01321349  0.01129358  0.00281738
#  -0.11167901]
# t:-0.19572435625979634
# y:[1.95875438e-02 3.16227764e-05 1.58113882e-05 7.48300357e-06
#  6.39572955e-06 1.59552315e-06 3.71321267e+01]
# fluxes:[ 0.          0.05583918  0.02791795  0.01321427  0.01129425  0.00281754
#  -0.11167895]
# t:-0.19572435625979634
# y:[1.95875438e-02 3.16225902e-05 1.58103686e-05 7.48344418e-06
#  6.39610614e-06 1.59561710e-06 3.71321267e+01]
# fluxes:[ 0.          0.05583918  0.02791795  0.01321427  0.01129425  0.00281754
#  -0.11167895]
# fluxes:[ 0.00200142 -0.73570138 -0.00751962  0.93343891  0.79781103  0.19902749
#  -0.22859852]
# t:52.10894324577052
# y:[8.79920930e-01 2.75679770e+00 1.29285139e-02 2.69700118e+01
#  2.30512921e+01 5.75053556e+00 3.79518248e-01]
# fluxes:[ 0.00200135 -0.73591563 -0.00755523  0.93346054  0.79782952  0.1990321
#  -0.22833489]
# t:52.33548514148919
# y:[8.80151010e-01 2.59242221e+00 1.13231616e-02 2.71770410e+01
#  2.32282402e+01 5.79467826e+00 3.31411970e-01]
# fluxes:[ 1.12903373e-04 -7.12533182e-01 -6.63469344e-03  8.95061687e-01
#   7.65009989e-01  1.90844709e-01 -2.00367002e-01]
# t:52.33548514148919
# y:[8.80160405e-01 2.59270626e+00 1.13171744e-02 2.71771327e+01
#  2.32283185e+01 5.79469779e+00 3.30988639e-01]
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# ---------------------------------------------------------------------------
# Infeasible                                Traceback (most recent call last)
# File <timed exec>:4
#
# File ~/Ruminiclostridium_cellulolyticum_model/Ruminiclostridium-cellullolyticum-model-final/functions/dfba_param_opt_cobra_cellulose.py:131, in optimize_parameters_inner_problem_cellulose(combination, model, media, rxns, y0, objective_dir, glc_eq_dict, alternative_solution, t_end)
#     123     ts = np.linspace(biomass_exp.iloc[0,0], biomass_exp.iloc[biomass_exp["x"].size-1,0], 1000)
#     125 #model.reactions.EX_etoh_e.add_metabolites({"ratio_R_EX_ac_e_R_EX_etoh_e":-ratio_ac_etoh})
#     126 #model.reactions.EX_lac__L_e.add_metabolites({"ratio_R_EX_ac_e_R_EX_lac__L_e":-ratio_ac_lac})
#     127
#     128 #model.repair()
#     129 #cobra.util.add_lp_feasibility(model)
# --> 131 sol = solve_ivp(
#     132     fun=dynamic_system_cellulose,
#     133     t_span=(ts.min(), ts.max()),
#     134     y0=y0,
#     135     t_eval=ts,
#     136     method='LSODA',
#     137     events = [infeasible_event],
#     138     args = (model,rxns,objective_dir,glc_eq_dict,combination)
#     139 )
#     140 #except:
#     141
#     142     #coeff1 = model.reactions.EX_etoh_e.get_coefficient("ratio_R_EX_ac_e_R_EX_etoh_e")
#     143     #coeff2 = model.reactions.EX_lac__L_e.get_coefficient("ratio_R_EX_ac_e_R_EX_lac__L_e")
#     144     #print(f"had issues with this combination: {combination}, the ratio_R_EX_ac_e_R_EX_etoh_e is:{coeff1} and the ratio_R_EX_ac_e_R_EX_lac__L_e is {coeff2}")
#     147 C_dict_results = dict(zip(rxns,sol.y))
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py:576, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574 status = None
#     575 while status is None:
# --> 576     message = solver.step()
#     578     if solver.status == 'finished':
#     579         status = 0
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ivp/lsoda.py:148, in LSODA._step_impl(self)
#     146 itask = integrator.call_args[2]
#     147 integrator.call_args[2] = 5
# --> 148 solver._y, solver.t = integrator.run(
#     149     solver.f, solver.jac or (lambda: None), solver._y, solver.t,
#     150     self.t_bound, solver.f_params, solver.jac_params)
#     151 integrator.call_args[2] = itask
#     153 if solver.successful():
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ode.py:1346, in lsoda.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1343     self.acquire_new_handle()
#    1344 args = [f, y0, t0, t1] + self.call_args[:-1] + \
#    1345        [jac, self.call_args[-1], f_params, 0, jac_params]
# -> 1346 y1, t, istate = self.runner(*args)
#    1347 self.istate = istate
#    1348 if istate < 0:
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py:514, in solve_ivp.<locals>.<lambda>(t, x, fun)
#     508 t0, tf = float(t_span[0]), float(t_span[1])
#     510 if args is not None:
#     511     # Wrap the user's fun (and jac, if given) in lambdas to hide the
#     512     # additional parameters.  Pass in the original fun as a keyword
#     513     # argument to keep it in the scope of the lambda.
# --> 514     fun = lambda t, x, fun=fun: fun(t, x, *args)
#     515     jac = options.get('jac')
#     516     if callable(jac):
#
# File ~/Ruminiclostridium_cellulolyticum_model/Ruminiclostridium-cellullolyticum-model-final/functions/dfba_param_opt_cobra_cellulose.py:93, in dynamic_system_cellulose(t, y, model, rxns, objective_dir, glc_eq_dict, combination)
#      91     cellulase = add_dynamic_bounds(model, conc_dict,glc_eq_dict,vmax_inner_glc, Km_inner_glc,vmax_inner_cellb, Km_inner_cellb, vmax_outer, Km_outer,Ki)
#      92     feasibility = cobra.util.fix_objective_as_constraint(model)
# ---> 93     lex_constraints = cobra.util.add_lexicographic_constraints(model, rxns_map, objective_dir)
#      95 # Since the calculated fluxes are specific rates, we multiply them by the
#      96 # biomass concentration to get the bulk exchange rates.
#      97 fluxes =lex_constraints.values
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/cobra/util/solver.py:679, in add_lexicographic_constraints(model, objectives, objective_direction)
#     677     model.objective = model.reactions.get_by_id(rxn_id)
#     678     model.objective_direction = obj_dir
# --> 679     constraints.append(fix_objective_as_constraint(model))
#     681 return pd.Series(constraints, index=objectives)
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/cobra/util/solver.py:513, in fix_objective_as_constraint(model, fraction, bound, name)
#     511     model.solver.remove(fix_objective_name)
#     512 if bound is None:
# --> 513     bound = model.slim_optimize(error_value=None) * fraction
#     514 if model.objective.direction == "max":
#     515     ub, lb = None, bound
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/cobra/core/model.py:1063, in Model.slim_optimize(self, error_value, message)
#    1061     return error_value
#    1062 else:
# -> 1063     assert_optimal(self, message)
#
# File ~/opt/anaconda3/envs/rcell_rec/lib/python3.8/site-packages/cobra/util/solver.py:590, in assert_optimal(model, message)
#     588 if status != OPTIMAL:
#     589     exception_cls = OPTLANG_TO_EXCEPTIONS_DICT.get(status, OptimizationError)
# --> 590     raise exception_cls(f"{message} ({status}).")
#
# Infeasible: None (infeasible).

# %%
from dfba_param_opt_cobra_cellulose import add_dynamic_bounds

# %%
model = read_model(media)

# %%
y = [0.880160405, 2.59270626, 0.0113171744, 27.1771327,
 23.2283185, 5.79469779, 0.330988639]
conc_dict =  dict(zip(rxns,y))

# %%
cellulase = add_dynamic_bounds(model, conc_dict,glc_eq_dict,
                   vmax_inner_glc=3.57063675,
                   Km_inner_glc=7.43223245,
                   vmax_inner_cellb=5.22655188,
                   Km_inner_cellb=0.90691345,
                   vmax_outer=7.27610953,
                   Km_outer=10.25470161,
                   Ki=18.18596756)


#[ 3.57063675,7.43223245,5.22655188,0.90691345,7.27610953,10.25470161,18.18596756]

# %%
rxns_map = copy.copy(rxns)
rxns_map.remove("EX_cellulose_e")

# %%
model.medium
# Out:
# {'EX_ac_e': 0,
#  'EX_ca2_e': 100,
#  'EX_cellb_e': 0.06441714920503566,
#  'EX_cl_e': 100,
#  'EX_cobalt2_e': 100,
#  'EX_cu2_e': 100,
#  'EX_fe2_e': 100,
#  'EX_fe3_e': 100,
#  'EX_glc__D_e': 0.9234582396674875,
#  'EX_h2o_e': 100,
#  'EX_h_e': 100,
#  'EX_k_e': 100,
#  'EX_mg2_e': 100,
#  'EX_mn2_e': 100,
#  'EX_nh4_e': 100,
#  'EX_pi_e': 100,
#  'EX_ribflv_e': 100,
#  'EX_so4_e': 100,
#  'EX_zn2_e': 100}

# %%
feasibility = cobra.util.fix_objective_as_constraint(model)

feasibility
# Out:
# -6.704509919017564e-09

# %%
lex_constraints = cobra.util.add_lexicographic_constraints(model, rxns_map, objective_dir)
lex_constraints
# Out:
# Growth         0.000128
# EX_glc__D_e   -0.923458
# EX_cellb_e    -0.064417
# EX_ac_e        1.016950
# EX_etoh_e      0.869188
# EX_lac__L_e    0.216834
# dtype: float64

# %%
# Since the calculated fluxes are specific rates, we multiply them by the
# biomass concentration to get the bulk exchange rates.
fluxes =lex_constraints.values
i = 1 
for key, glc_eq in glc_eq_dict.items():
    uptake = fluxes[i]
    fluxes[i] = uptake - cellulase/(glc_eq*len(glc_eq_dict)) # 1 mol of cellulase produces one mol of glucose equivalents
    i +=1

fluxes =np.append(fluxes, cellulase)
fluxes *= conc_dict["Growth"]

print(f"fluxes: {fluxes} \n")
# Out:
# fluxes: [ 1.49679374e-06  4.38006705e-02  2.78206839e-02  1.88822598e-02
#   1.82121893e-02  4.51834283e-03 -1.20257843e-01]

# %%
penalty_dict
# Out:
# {'penalty_growth': 300.33915792101647,
#  'penalty_cellulose': 72.43274879546254,
#  'penalty_acetate': 86.07661805258192,
#  'penalty_ethanol': 66.37717702448859,
#  'penalty_lac': 14.793521817248923}

# %%
C_dict_results = dict(zip(rxns,sol.y))

# %%
fig,ax = plt.subplots(1,4,figsize=(15,5))

ax[0].plot(sol.t,C_dict_results["Growth"],label="Biomass")

ax[0].plot(biomass_exp.x,biomass_exp["y g"],'x',color="tab:blue")
ax[0].legend()

ax[1].plot(sol.t,C_dict_results["EX_cellulose_e"],label="Cellulose")
ax[1].plot(cellulose_exp.x,cellulose_exp["y mmol"],'x',color="tab:blue")
ax[1].legend()

ax[2].plot(sol.t,C_dict_results["EX_cellb_e"],label="Cellobiose")
ax[2].plot(cellb_exp.x,cellb_exp[" y"],'x',color="tab:blue")

ax[2].plot(sol.t,C_dict_results["EX_glc__D_e"],color="r",label="Glucose")
ax[2].plot(glc_exp.x,glc_exp[" y"],'x',color="r")

ax[2].legend()


ax[3].plot(sol.t,C_dict_results["EX_ac_e"],color="r",label="Acetate")
ax[3].plot(acetate_exp.x,acetate_exp[" y"],'x',color="r")


ax[3].plot(sol.t,C_dict_results["EX_etoh_e"],color="b",label="Ethanol")
ax[3].plot(ethanol_exp.x,ethanol_exp[" y"],'x',color="b")

ax[3].plot(sol.t,C_dict_results["EX_lac__L_e"],color="g",label="Lactate")
ax[3].plot(lactate_exp.x,lactate_exp[" y"],'x',color="g")
ax[3].legend()

# %% [markdown]
# #### Testing out a combination closer to the best values

# %%
combination = [6.01,0.2,5.01,0.2,2.9,4.4,11,0,0]

# %% [raw]
# %%time
# model = read_model(media)
# result = minimize_parallel(optimize_parameters_inner_problem_cellulose,
#                   combination,
#                   bounds=[(0.1,10),(0.1,20),(0.1,10),(0.1,20),(0.1,10),(0.1,20),(0.1,20),(0,0.5),(-2,2)],
#                   args=(model,media,rxns,y0,objective_dir,glc_eq_dict),
#                  options ={'maxiter':100,'gtol': 1e-3,'ftol':1e-4},
#                   parallel = {'max_workers':4,'verbose':False})

# %% [markdown]
# CPU times: user 13.1 s, sys: 2.22 s, total: 15.3 s
# Wall time: 41min 41s

# %%
pd.Series({"result.x":[ 5.51984901,  0.18524121,  5.42517869,  0.1902395 ,  2.66153537,
        4.02279575, 11.73930932,  0.11992288,  0.04280795],
"result.success":True,
"results.convergence":"CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH",
"result.fun":21.353895719513883
})
# Out:
# result.x               [5.51984901, 0.18524121, 5.42517869, 0.1902395...
# result.success                                                      True
# results.convergence      CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# result.fun                                                     21.353896
# dtype: object

# %%
combination = result.x


model = read_model(media)
sol,penalty,penalty_dict = optimize_parameters_inner_problem_cellulose(combination=combination,model=model,media=media,rxns=rxns,y0=y0,objective_dir=objective_dir,glc_eq_dict=glc_eq_dict,alternative_solution=True,t_end=150)

# %%
penalty_dict
# Out:
# {'penalty_growth': 6.990038387647931,
#  'penalty_cellulose': 4.357499622605967,
#  'penalty_acetate': 1.1148768296961604,
#  'penalty_ethanol': 8.83632170804648,
#  'penalty_lac': 0.05621924015412904}

# %%
C_dict_results = dict(zip(rxns,sol.y))

# %%
fig,ax = plt.subplots(1,4,figsize=(15,5))

ax[0].plot(sol.t,C_dict_results["Growth"],label="Biomass")

ax[0].plot(biomass_exp.x,biomass_exp["y g"],'x',color="tab:blue")
ax[0].legend()

ax[1].plot(sol.t,C_dict_results["EX_cellulose_e"],label="Cellulose")
ax[1].plot(cellulose_exp.x,cellulose_exp["y mmol"],'x',color="tab:blue")
ax[1].legend()

ax[2].plot(sol.t,C_dict_results["EX_cellb_e"],label="Cellobiose")
ax[2].plot(cellb_exp.x,cellb_exp[" y"],'x',color="tab:blue")

ax[2].plot(sol.t,C_dict_results["EX_glc__D_e"],color="r",label="Glucose")
ax[2].plot(glc_exp.x,glc_exp[" y"],'x',color="r")

ax[2].legend()


ax[3].plot(sol.t,C_dict_results["EX_ac_e"],color="r",label="Acetate")
ax[3].plot(acetate_exp.x,acetate_exp[" y"],'x',color="r")


ax[3].plot(sol.t,C_dict_results["EX_etoh_e"],color="b",label="Ethanol")
ax[3].plot(ethanol_exp.x,ethanol_exp[" y"],'x',color="b")

ax[3].plot(sol.t,C_dict_results["EX_lac__L_e"],color="g",label="Lactate")
ax[3].plot(lactate_exp.x,lactate_exp[" y"],'x',color="g")
ax[3].legend()

# %% [markdown]
# #### Another combination

# %%
combination = [ 3.51984901,  1.18524121,  3.42517869,  1.1902395 ,  4.66153537,
        10, 11.73930932,  0.2,  0.04280795]

# %%
model = read_model(media)
sol,penalty,penalty_dict = optimize_parameters_inner_problem_cellulose(combination=combination,model=model,media=media,rxns=rxns,y0=y0,objective_dir=objective_dir,glc_eq_dict=glc_eq_dict,alternative_solution=True,t_end=150)
# Out:
# [3.51984901, 1.18524121, 3.42517869, 1.1902395, 4.66153537, 10, 11.73930932, 0.2, 0.04280795]
# 1-r2: 263.7990873615984

# %%
penalty_dict
# Out:
# {'penalty_growth': 62.169497412241164,
#  'penalty_cellulose': 128.48593222620303,
#  'penalty_acetate': 29.307825793262936,
#  'penalty_ethanol': 39.70942101407155,
#  'penalty_lac': 4.126410915819728}

# %%
C_dict_results = dict(zip(rxns,sol.y))

# %%
fig,ax = plt.subplots(1,4,figsize=(15,5))

ax[0].plot(sol.t,C_dict_results["Growth"],label="Biomass")

ax[0].plot(biomass_exp.x,biomass_exp["y g"],'x',color="tab:blue")
ax[0].legend()

ax[1].plot(sol.t,C_dict_results["EX_cellulose_e"],label="Cellulose")
ax[1].plot(cellulose_exp.x,cellulose_exp["y mmol"],'x',color="tab:blue")
ax[1].legend()

ax[2].plot(sol.t,C_dict_results["EX_cellb_e"],label="Cellobiose")
ax[2].plot(cellb_exp.x,cellb_exp[" y"],'x',color="tab:blue")

ax[2].plot(sol.t,C_dict_results["EX_glc__D_e"],color="r",label="Glucose")
ax[2].plot(glc_exp.x,glc_exp[" y"],'x',color="r")

ax[2].legend()


ax[3].plot(sol.t,C_dict_results["EX_ac_e"],color="r",label="Acetate")
ax[3].plot(acetate_exp.x,acetate_exp[" y"],'x',color="r")


ax[3].plot(sol.t,C_dict_results["EX_etoh_e"],color="b",label="Ethanol")
ax[3].plot(ethanol_exp.x,ethanol_exp[" y"],'x',color="b")

ax[3].plot(sol.t,C_dict_results["EX_lac__L_e"],color="g",label="Lactate")
ax[3].plot(lactate_exp.x,lactate_exp[" y"],'x',color="g")
ax[3].legend()
