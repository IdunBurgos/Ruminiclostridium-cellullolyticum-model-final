# %% [markdown]
# # Other simulations

# %%
import numpy as np
from tqdm import tqdm

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline

from collections import OrderedDict

# %%
import cobra
from cobra.io import load_model

import pandas as pd
import copy

import molmass
import reframed

from scipy.interpolate import interp1d
from sklearn.metrics import r2_score

# %% [markdown]
# ## Mechanisms involved in xyloglucan catabolism by the cellulosome-producing bacterium Ruminiclostridium cellulolyticum ([Ravachol et al. 2016](https://www.nature.com/articles/srep22770#MOESM79))

# %%
def add_dynamic_bounds(model, conc_dict,glc_eq_dict,vmax_inner,Km_inner,vmax_outer,Km_outer,Ki):
    """Use external concentrations to bound the uptake flux of glucose."""    
    for key in glc_eq_dict.keys():
        
        max_import = -vmax_inner * conc_dict[key] / (Km_inner + conc_dict[key])
        model.reactions.get_by_id(key).lower_bound = max_import
        
    cellulase = -vmax_outer*(conc_dict["EX_xylogluc_e"]/((1 + (conc_dict["EX_QQQG_e"]/Ki))*Km_outer + conc_dict["EX_xylogluc_e"]))
    model.reactions.EX_cellb_e.lower_bound = 0
    return cellulase

def dynamic_system(t, y,rxns,objective_dir,glc_eq_dict,vmax_inner,Km_inner,vmax_outer,Km_outer,Ki):
    """Calculate the time derivative of external species."""    
    rxns_map = copy.copy(rxns)
    rxns_map.remove("EX_xylogluc_e")
    conc_dict = dict(zip(rxns,y))
    
    # Calculate the specific exchanges fluxes at the given external concentrations.
    with model:
        cellulase = add_dynamic_bounds(model, conc_dict,glc_eq_dict,vmax_inner,Km_inner,vmax_outer,Km_outer,Ki)
        print(f"model medium {model.medium}")
        feasibility = cobra.util.fix_objective_as_constraint(model)
        lex_constraints = cobra.util.add_lexicographic_constraints(model, rxns_map, objective_dir)
        
    # Since the calculated fluxes are specific rates, we multiply them by the
    # biomass concentration to get the bulk exchange rates.
    fluxes =lex_constraints.values
    i = 1 
    for key, glc_eq in glc_eq_dict.items():
        uptake = fluxes[i]
        fluxes[i] = uptake - cellulase/glc_eq # 1 mol of cellulase produces one mol of glucose equivalents
        i +=1
        
    fluxes =np.append(fluxes, cellulase/glc_eq)
    #print(f"fluxes (growth,QQQG,cellulase): {fluxes}")
    print(fluxes)
    fluxes *= conc_dict["Growth"]

    if dynamic_system.pbar is not None:
        dynamic_system.pbar.update(1)
        dynamic_system.pbar.set_description('t = {:.3f}'.format(t))
    
    return fluxes

dynamic_system.pbar = None


def optimize_parameters_inner_problem(combination,media,rxns,objective_dir,xylog_glc_eq_dict):
    vmax_inner_option, km_inner_option, vmax_outer_option, km_outer_option,ki_option = combination

    print((vmax_inner_option,km_inner_option,vmax_outer_option,km_outer_option,ki_option))

    model = cobra.io.read_sbml_model('../models/RcH10_final.xml')
    exchanges_ids = [rxn.id for rxn in model.exchanges]

    media_exchanges = ["EX_"+met+"_e" for met in media["DM_xyloglucan"]]
    medium = model.medium

    for exchange in exchanges_ids:
        if exchange in ["EX_xyl__D_e","EX_glc__D_e","EX_cellb_e","EX_gal_e","EX_gal__L_e"]:
            medium[exchange]=0

        elif exchange in media_exchanges:
            medium[exchange]=100 

        else: 
            medium[exchange]=0

    model.medium = medium

    cobra.util.add_lp_feasibility(model)

    ts = np.linspace(OD.iloc[0,0], 70, 1000)  

    sol = solve_ivp(
        fun=dynamic_system,
        t_span=(ts.min(), ts.max()),
        y0=y0,
        t_eval=ts,
        method='LSODA',
        args = (rxns,objective_dir,xylog_glc_eq_dict,vmax_inner_option,km_inner_option,vmax_outer_option,km_outer_option,ki_option)
    )

    interp_func = interp1d(sol.t, sol.y.T[:,0], kind='linear', fill_value="extrapolate")
    y_interp = interp_func(OD.x.values)
    r2_score_spec = r2_score(OD[" y"].values,y_interp)
    print(f"r2: {r2_score_spec}")
    
    return sol,r2_score_spec

# %%
import itertools

# %% [markdown]
# ### Optimizing parameters

# %%
vmax_inner_options = np.linspace(2,4,4)
km_inner_options = np.linspace(0.5,1.5,4)
vmax_outer_options = np.linspace(0.5,1.5,4)
km_outer_options = np.linspace(2,4,4)
ki_options = np.logspace(0,1,4)

combinations = list(itertools.product(vmax_inner_options, km_inner_options, vmax_outer_options,km_outer_options,ki_options))

OD = pd.read_csv("../input/Ravachol2016_batch_data/OD_xyloglucan.csv")
OD[" y"] = OD[" y"]*0.5

model = cobra.io.read_sbml_model('../models/RcH10_final.xml')
formula = model.metabolites.get_by_id("QQQG_e").notes["FORMULA"]
molarmass = molmass.Formula(formula).mass

xylog_glc_eq_dict =OrderedDict({
"EX_QQQG_e": 39/6})

C_dict =OrderedDict({
"Growth":OD.iloc[0,1],
"EX_QQQG_e": 0,
"EX_xylogluc_e": 3.5*1000/(molarmass/xylog_glc_eq_dict["EX_QQQG_e"])
})

rxns = list(C_dict.keys())
y0 = np.array(list(C_dict.values()))

objective_dir = ["max", "max"]
best_r2 = {}

media = pd.read_csv('../input/media_db.tsv',sep='\t')
media = media.groupby('medium').agg({'compound': set})['compound'].to_dict()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-03-14

# %%
len(combinations)
# Out:
# 1024

# %%
for combination in combinations:
    sol, r2_score_spec = optimize_parameters_inner_problem(combination=combination,media=media,rxns=rxns,objective_dir=objective_dir,xylog_glc_eq_dict=xylog_glc_eq_dict)
    best_r2[combination] = r2_score_spec
# Out:
# (2.0, 0.5, 0.5, 2.0, 1.0)
# r2: -1.1798070833091434
# (2.0, 0.5, 0.5, 2.0, 2.154434690031884)
# r2: -1.178389067300054
# (2.0, 0.5, 0.5, 2.0, 4.641588833612778)
# r2: -1.1777285598024005
# (2.0, 0.5, 0.5, 2.0, 10.0)
# r2: -1.1774211318308194
# (2.0, 0.5, 0.5, 2.6666666666666665, 1.0)
# r2: -1.2307457552756103
# (2.0, 0.5, 0.5, 2.6666666666666665, 2.154434690031884)
# r2: -1.2291424552498795
# (2.0, 0.5, 0.5, 2.6666666666666665, 4.641588833612778)
# r2: -1.22839551705242
# (2.0, 0.5, 0.5, 2.6666666666666665, 10.0)
# r2: -1.2280482231475842
# (2.0, 0.5, 0.5, 3.333333333333333, 1.0)
# r2: -1.2762605186645324
# (4.0, 1.5, 1.5, 2.6666666666666665, 10.0)
# r2: -108.12265487482748
# (4.0, 1.5, 1.5, 3.333333333333333, 1.0)
# r2: -65.39137706542725
# (4.0, 1.5, 1.5, 3.333333333333333, 2.154434690031884)
# r2: -70.03963596777442
# (4.0, 1.5, 1.5, 3.333333333333333, 4.641588833612778)
# r2: -72.27413356522582
# (4.0, 1.5, 1.5, 3.333333333333333, 10.0)
# r2: -73.34149422102651
# (4.0, 1.5, 1.5, 4.0, 1.0)
# r2: -44.005865972823315
# (4.0, 1.5, 1.5, 4.0, 2.154434690031884)
# r2: -47.49306258088049
# (4.0, 1.5, 1.5, 4.0, 4.641588833612778)
# r2: -49.22457875827323
# (4.0, 1.5, 1.5, 4.0, 10.0)
# r2: -50.054245242681105

# %%
best_r2_ser = pd.Series(best_r2)
best_r2_ser.index.names = ["vmax_inner_option","km_inner_option","vmax_outer_option","km_outer_option","ki_option"]
best_r2_ser.name = "r2"

# %%
best_r2_ser.sort_values(ascending=False).head(20)
# Out:
# vmax_inner_option  km_inner_option  vmax_outer_option  km_outer_option  ki_option
# 2.666667           1.500000         1.166667           4.000000         1.000000     0.988929
# 2.000000           1.166667         1.166667           4.000000         10.000000    0.987873
#                                                                         4.641589     0.987416
# 2.666667           1.500000         1.166667           4.000000         2.154435     0.986827
# 2.000000           1.166667         1.166667           4.000000         2.154435     0.985947
# 2.666667           1.500000         1.166667           4.000000         4.641589     0.984714
#                                                                         10.000000    0.983465
# 2.000000           1.500000         1.166667           2.000000         1.000000     0.982742
#                                                                         2.154435     0.982435
#                                                                         4.641589     0.981705
#                                                                         10.000000    0.981232
#                    1.166667         1.166667           4.000000         1.000000     0.980585
#                                                        3.333333         1.000000     0.976503
#                                                                         2.154435     0.966364
#                                                                         4.641589     0.960424
#                                                                         10.000000    0.957380
#                    1.500000         1.166667           2.666667         10.000000    0.956961
#                                                                         4.641589     0.954755
#                                                                         2.154435     0.949754
# 2.666667           1.500000         1.166667           3.333333         1.000000     0.941586
# Name: r2, dtype: float64

# %%
best_r2_ser = pd.Series(best_r2)
best_r2_ser.index.names = ["vmax_inner_option","km_inner_option","vmax_outer_option","km_outer_option","ki_option"]
best_r2_ser.name = "r2"

# %%
best_r2_ser.sort_values(ascending=False).head(20)
# Out:
# vmax_inner_option  km_inner_option  vmax_outer_option  km_outer_option  ki_option
# 3.162278           1.0              1.000000           3.162278         1.0          0.982069
#                                                                         10.0         0.981730
#                                                                         0.1          0.915061
# 1.000000           10.0             10.000000          1.000000         0.1          0.874818
#                                                        10.000000        10.0         0.775040
# 10.000000          0.1              1.000000           10.000000        10.0         0.641825
#                                                                         1.0          0.640418
#                                                                         0.1          0.626339
# 3.162278           0.1              1.000000           10.000000        10.0         0.598101
#                                                                         1.0          0.593476
#                    10.0             3.162278           10.000000        10.0         0.565944
#                    0.1              1.000000           10.000000        0.1          0.547441
#                    1.0              1.000000           1.000000         0.1          0.543926
# 1.000000           0.1              1.000000           3.162278         0.1          0.524700
# 3.162278           10.0             3.162278           3.162278         0.1          0.497074
# 10.000000          1.0              1.000000           10.000000        10.0         0.459090
#                                                                         1.0          0.442979
# 1.000000           0.1              1.000000           10.000000        10.0         0.434559
#                                                                         1.0          0.418562
# 10.000000          1.0              1.000000           3.162278         0.1          0.405434
# Name: r2, dtype: float64

# %% [markdown]
# ### Best result from large range with Ki value

# %%
sol, r2 = optimize_parameters_inner_problem(combination=(2.666667 ,1.500000,1.166667 ,4.000000, 1.000000),media=media,rxns=rxns,objective_dir=objective_dir,xylog_glc_eq_dict=xylog_glc_eq_dict)
# Out:
# (2.666667, 1.5, 1.166667, 4.0, 1.0)
# r2: 0.9889285178730813

# %%
C_dict_results = dict(zip(C_dict.keys(),sol.y))

# %%
fig,ax = plt.subplots(1,3,figsize=(10,4))
ax[0].plot(sol.t, C_dict_results["Growth"],label = 'Biomass',color="tab:blue")
ax[0].legend()
ax[0].set_ylabel('Concentration [g/L]')
ax[0].plot(OD.x,OD[" y"],'x',color="tab:blue")


ax[1].plot(sol.t, C_dict_results["EX_xylogluc_e"], color='g',label='Xyloglucan')
#ax[1].set_ylim([0,3])
ax[1].legend()
ax[1].set_ylabel('Concentration [mmol/L]')

colors = ['r','g','y','b','pink']

ax[2].plot(sol.t, C_dict_results["EX_QQQG_e"], color='r',label="QQQG")
ax[2].legend()
ax[2].set_ylabel('Concentration [mmol/L]')
plt.tight_layout()

# %%
sol, r2 = optimize_parameters_inner_problem(combination=(2.000000,1.166667,1.166667,4.000000,10.000000 ),media=media,rxns=rxns,objective_dir=objective_dir,xylog_glc_eq_dict=xylog_glc_eq_dict)
# Out:
# (2.0, 1.166667, 1.166667, 4.0, 10.0)
# r2: 0.9878733637104267

# %%
C_dict_results = dict(zip(C_dict.keys(),sol.y))

# %%
fig,ax = plt.subplots(1,3,figsize=(10,4))
ax[0].plot(sol.t, C_dict_results["Growth"],label = 'Biomass',color="tab:blue")
ax[0].legend()
ax[0].set_ylabel('Concentration [g/L]')
ax[0].plot(OD.x,OD[" y"],'x',color="tab:blue")


ax[1].plot(sol.t, C_dict_results["EX_xylogluc_e"], color='g',label='Xyloglucan')
#ax[1].set_ylim([0,3])
ax[1].legend()
ax[1].set_ylabel('Concentration [mmol/L]')

colors = ['r','g','y','b','pink']

ax[2].plot(sol.t, C_dict_results["EX_QQQG_e"], color='r',label="QQQG")
ax[2].legend()
ax[2].set_ylabel('Concentration [mmol/L]')
plt.tight_layout()

# %%
old = pd.read_csv("../output/optimize_parameters/r2_with_ki_large_range.csv")
semi_old =pd.read_csv("../output/optimize_parameters/r2_with_ki_small_range.csv")

# %%
new = best_r2_ser.reset_index()

# %%
df = pd.concat([old,semi_old,new])

df.drop_duplicates(inplace=True)

# %%
df.vmax_inner_option = df.vmax_inner_option.map(lambda x:round(x,3))
df.km_inner_option = df.km_inner_option.map(lambda x:round(x,3))
df.vmax_outer_option = df.vmax_outer_option.map(lambda x:round(x,3))
df.km_outer_option = df.km_outer_option.map(lambda x:round(x,3))
df.ki_option = df.ki_option.map(lambda x:round(x,3))

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots()
sns.violinplot(ax=ax,data=df[df.r2>-1],x="vmax_inner_option",y="r2",alpha=0.7,cut=0)
# Out:
# <AxesSubplot:xlabel='vmax_inner_option', ylabel='r2'>

# %%
sns.violinplot(data=df[df.r2>-1],x="km_inner_option",y="r2",alpha=0.7,cut=0)
# Out:
# <AxesSubplot:xlabel='km_inner_option', ylabel='r2'>

# %%
sns.violinplot(data=df[df.r2>-1],x="vmax_outer_option",y="r2",alpha=0.7,cut=0)
# Out:
# <AxesSubplot:xlabel='vmax_outer_option', ylabel='r2'>

# %%
sns.violinplot(data=df[df.r2>-1],x="km_outer_option",y="r2",alpha=0.7,cut=0)
# Out:
# <AxesSubplot:xlabel='km_outer_option', ylabel='r2'>

# %%
sns.violinplot(data=df[df.r2>-1],x="ki_option",y="r2",alpha=0.7,cut=0)
# Out:
# <AxesSubplot:xlabel='ki_option', ylabel='r2'>

# %% [markdown]
# ### Oligosaccharides

# %%
import numpy as np
from tqdm import tqdm

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline

from collections import OrderedDict

# %%
import cobra
from cobra.io import load_model

import pandas as pd
import copy

import molmass
import reframed

from scipy.interpolate import interp1d
from sklearn.metrics import r2_score

# %%
import itertools

# %%
OD_oligo = pd.read_csv("../input/Ravachol2016_batch_data/OD_oligosaccharide.csv")

OD_oligo[" y"] = OD_oligo[" y"]*0.5
OD_oligo
# Out:
#             x         y
# 0    0.054563  0.010998
# 1   23.968407  0.012747
# 2   93.159978  0.150311
# 3   96.785936  0.172056
# 4  118.661109  0.297234
# 5  120.714660  0.312463
# 6  143.739090  0.437361

# %%
model = cobra.io.read_sbml_model('../models/RcH10_final.xml')
formula = model.metabolites.get_by_id("QQQG_e").notes["FORMULA"]
molarmass = molmass.Formula(formula).mass

xylog_glc_eq_dict =OrderedDict({
"EX_QQQG_e": 39/6})


C_dict =OrderedDict({
"Growth":OD_oligo.iloc[0,1],
"EX_QQQG_e": 3.5*1000/molarmass,
"EX_xylogluc_e":0})

rxns = list(C_dict.keys())
y0 = np.array(list(C_dict.values()))

objective_dir = ["max", "max"]
best_r2 = {}

media = pd.read_csv('../input/media_db.tsv',sep='\t')
media = media.groupby('medium').agg({'compound': set})['compound'].to_dict()

# %%
def optimize_parameters_inner_problem(combination,media,rxns,objective_dir,xylog_glc_eq_dict):
    vmax_inner_option, km_inner_option, vmax_outer_option, km_outer_option,ki_option = combination

    print((vmax_inner_option,km_inner_option,vmax_outer_option,km_outer_option,ki_option))

    model = cobra.io.read_sbml_model('../models/RcH10_final.xml')
    exchanges_ids = [rxn.id for rxn in model.exchanges]

    media_exchanges = ["EX_"+met+"_e" for met in media["DM_xyloglucan"]]
    medium = model.medium

    for exchange in exchanges_ids:
        if exchange in ["EX_xyl__D_e","EX_glc__D_e","EX_cellb_e","EX_gal_e","EX_gal__L_e"]:
            medium[exchange]=0

        elif exchange in media_exchanges:
            medium[exchange]=100 

        else: 
            medium[exchange]=0

    model.medium = medium

    cobra.util.add_lp_feasibility(model)

    ts = np.linspace(OD_oligo.iloc[0,0], 5, 1000)  

    sol = solve_ivp(
        fun=dynamic_system,
        t_span=(ts.min(), ts.max()),
        y0=y0,
        t_eval=ts,
        method='LSODA',
        args = (rxns,objective_dir,xylog_glc_eq_dict,vmax_inner_option,km_inner_option,vmax_outer_option,km_outer_option,ki_option)
    )
   
    return sol

# %%
sol = optimize_parameters_inner_problem(combination=(2.666667 ,1.500000,1.166667 ,4.000000, 1.000000),media=media,rxns=rxns,objective_dir=objective_dir,xylog_glc_eq_dict=xylog_glc_eq_dict)
# Out:
# (2.666667, 1.5, 1.166667, 4.0, 1.0)
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.8320826765963485}
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.8319162087199716}
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.8319107449304657}
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.8317383837535386}
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.6788257772854436}
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.6643260891261458}
# model medium {'EX_ca2_e': 10.0, 'EX_cl_e': 10.0, 'EX_cobalt2_e': 10.0, 'EX_cu2_e': 10.0, 'EX_fe2_e': 10.0, 'EX_fe3_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 1000.0, 'EX_k_e': 10.0, 'EX_mg2_e': 10.0, 'EX_mn2_e': 10.0, 'EX_nh4_e': 10.0, 'EX_pi_e': 10.0, 'EX_ribflv_e': 10.0, 'EX_so4_e': 10.0, 'EX_zn2_e': 10.0, 'EX_QQQG_e': 1.664331348701865}

# %%
C_dict_results = dict(zip(C_dict.keys(),sol.y))

# %%
fig,ax = plt.subplots(1,2,figsize=(10,4))
ax[0].plot(sol.t, C_dict_results["Growth"],label = 'Biomass',color="tab:blue")
ax[0].legend()
ax[0].set_ylabel('Concentration [g/L]')
ax[0].plot(OD_oligo.x,OD_oligo[" y"],'x',color="tab:blue")


colors = ['r','g','y','b','pink']

ax[1].plot(sol.t, C_dict_results["EX_QQQG_e"], color='r',label="QQQG")
ax[1].legend()
ax[1].set_ylabel('Concentration [mmol/L]')
plt.tight_layout()

# %% [markdown]
# ## Mapping of carbon flow distribution in central metabolic pathway ... ([Desvaux 2004](https://koreascience.kr/article/JAKO200430710404636.pdf))

# %%
ammonia_limited = pd.read_csv("../input/Desvaux2004_chemostat_data/ammonia_limited.csv",)

ammonia_limited = ammonia_limited.loc[1:,~ammonia_limited.columns.str.contains("%")]
ammonia_limited.set_index("Carbon flow",inplace=True)

# %%
import reframed

# %%
model = reframed.load_cbmodel("../models/RcH10_final2.xml")
#model.reactions.R_EX_gal_e.ub=0
#model.reactions.R_EX_rib__D_e.ub=0
#model.reactions.R_EX_succ_e.=0
#model.reactions.R_LDH_D.ub=0
#model.reactions.R_LDH_D.lb=0
#model.add_ratio_constraint("R_EX_h2_e","R_EX_cellb_e",-4)

# %%
nh4_limiting = {}

for growth_rate_str in ammonia_limited.columns:
    growth_rate = float(growth_rate_str)
    
    model.reactions.Growth.lb = growth_rate
    model.reactions.Growth.ub = growth_rate
    
    sol = reframed.FBA(model,objective={"Growth":0,"R_EX_nh4_e":1})
    nh4_limiting[growth_rate] = sol.fobj

# %%
nh4_limiting
# Out:
# {0.023: -0.22752253200000538,
#  0.036: -0.35612222399999993,
#  0.052: -0.5143987680000031,
#  0.082: -0.8111672880000036}

# %%
model.reactions.Growth.lb = 0
model.reactions.Growth.ub = 1000

production = {}

for growth_rate, ammonia_uptake in nh4_limiting.items():

    sol = reframed.pFBA(model,constraints={"R_EX_nh4_e":(ammonia_uptake,0)})
    
    production[growth_rate] = {"q_acetate":sol.values["R_EX_ac_e"],
                              "q_ethanol":sol.values["R_EX_etoh_e"],
                              "q_lactate":sol.values["R_EX_lac__L_e"],
                              "q_pyr_ex":sol.values["R_EX_pyr_e"],
                              "q_co2":sol.values["R_EX_co2_e"]}

# %%
pd.DataFrame(production)
# Out:
#               0.023     0.036     0.052     0.082
# q_acetate  1.951142  2.157344  2.411130  2.886979
# q_ethanol  0.000000  0.000000  0.000000  0.000000
# q_lactate  0.000000  0.000000  0.000000  0.000000
# q_pyr_ex   0.000000  0.000000  0.000000  0.000000
# q_co2      1.983304  2.207684  2.483844  3.001643

# %%
ammonia_limited.iloc[13:,:]
# Out:
#                           0.023  0.036  0.052  0.082
# Carbon flow
# q_lactate                  0.69   0.79   2.94  87.20
# q_extracellular pyruvate    NaN    NaN   0.42   0.44
# q_carbon dioxide           1.88   2.35   2.78   2.89
# q_ethanol                  1.79   2.22   2.00   2.00
# q_acetate                  1.97   2.49   3.56   3.78

# %%
sol.show_values(pattern="R_EX_",sort=True)
# Out:
# R_EX_h2o_e   -3.14635
# R_EX_cellb_e -1.0386
# R_EX_nh4_e   -0.811167
# R_EX_so4_e   -0.52036
# R_EX_pi_e    -0.0717715
# R_EX_k_e     -0.0160058
# R_EX_mg2_e   -0.00071135
# R_EX_fe3_e   -0.000640256
# R_EX_fe2_e   -0.00055063
# R_EX_ca2_e   -0.00042681
# R_EX_cl_e    -0.00042681
# R_EX_cu2_e   -5.8138e-05
# R_EX_mn2_e   -5.6662e-05
# R_EX_ribflv_e -3.6572e-05
# R_EX_zn2_e   -2.7962e-05
# R_EX_cobalt2_e -8.2e-06
# R_EX_4hba_e   1.8286e-05
# R_EX_succ_e   0.0271718
# R_EX_d23hb_e  0.0308609
# R_EX_h2s_e    0.499809
# R_EX_h_e      2.72493
# R_EX_ac_e     2.99455
# R_EX_co2_e    3.10921
# R_EX_h2_e     4.15442

# %% [markdown]
# ## Whole Proteome Analyses on Ruminiclostridium cellulolyticum Show a Modulation of the Cellulolysis Machinery in Response to Cellulosic Materials with Subtle Differences in Chemical and Structural Properties ([Badalato et al. 2017](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5256962/))
#
#
# NB: Need to make sure that the media is good.

# %%
model = reframed.load_cbmodel("../models/RcH10_final2.xml")

# %%
DNA = ['M_datp_c',
'M_dctp_c',
'M_dgtp_c',
'M_dttp_c']


DNA_mass_list = []
for nucleo in DNA:
    
    molarmass_nuc = molmass.Formula(model.metabolites[nucleo].metadata["FORMULA"]).mass
    molarmass_h2o = molmass.Formula("H2O").mass
    stoichiometry = -model.reactions.Growth.stoichiometry[nucleo]
    total_g = (molarmass_nuc+molarmass_h2o)*stoichiometry/1000
    DNA_mass_list.append(total_g)
    
DNA_mass = sum(DNA_mass_list) # g DNA/1 g bio
print(f"g_DNA/g_bio: {DNA_mass}")
dna_genome_copies = (1e-9)/227703 # g DNA/genome copies - from article
# Out:
# g_DNA/g_bio: 0.0532797844354618

# %%
cotton_genome_count = pd.read_csv("../input/Badalato2017_batch_data/cotton_genome_count_ml.csv")
cotton_genome_count["Biomass [g/L]"] = cotton_genome_count[" y"].map(lambda x:(x*dna_genome_copies/DNA_mass)*1e8 *1e4) # x [(genome copy nr) * (1e-8)/mL] * dna_genome_copies [g_DNA/(genome copy nr)] / DNA_mass [g_DNA/g_bio] = concentration [(1e-8)*g_bio/(mL)] -> concentration 1e3*1e8 [g_bio/L]
cotton_biomass = cotton_genome_count.drop(" y",axis=1).set_index("x")
cotton_biomass.index.name="time [h]"
cotton_biomass.reset_index(inplace=True)

cotton_biomass
# Out:
#      time [h]  Biomass [g/L]
# 0    7.055952       0.002010
# 1   25.879545       0.015077
# 2   49.044302       0.021893
# 3   73.160304       0.059316
# 4   96.768620       0.083310
# 5  144.184762       0.111193
# 6  190.614034       0.136799

# %% [raw]
# cotton_genome_count = pd.read_csv("../input/Badalato2017_batch_data/cotton_genome_count_ml_2.csv")
# cotton_genome_count["Biomass [g/L]"] = cotton_genome_count[" y"].map(lambda x:(x*dna_genome_copies/DNA_mass)*1e8 *1e3) # x [(genome copy nr) * (1e-8)/mL] * dna_genome_copies [g_DNA/(genome copy nr)] / DNA_mass [g_DNA/g_bio] = concentration [(1e-8)*g_bio/(mL)] -> concentration 1e3*1e8 [g_bio/L]
# cotton_biomass = cotton_genome_count.drop(" y",axis=1).set_index("x")
# cotton_biomass.index.name="time [h]"
# cotton_biomass.reset_index(inplace=True)
#
# cotton_biomass

# %%
tissue_genome_count = pd.read_csv("../input/Badalato2017_batch_data/tissue_genome_count_ml.csv")
tissue_genome_count["Biomass [g/L]"] = tissue_genome_count[" y"].map(lambda x:(x*dna_genome_copies/DNA_mass)*1e8 *1e3) # x [(genome copy nr) * (1e-8)/mL] * dna_genome_copies [g_DNA/(genome copy nr)] / DNA_mass [g_DNA/g_bio] = concentration [(1e-8)*g_bio/(mL)] -> concentration 1e3*1e8 [g_bio/L]
tissue_biomass = tissue_genome_count.drop(" y",axis=1).set_index("x")
tissue_biomass.index.name="time [h]"
tissue_biomass.reset_index(inplace=True)
tissue_biomass
# Out:
#      time [h]  Biomass [g/L]
# 0    4.643996       0.001601
# 1   26.066587       0.003424
# 2   49.165435       0.002734
# 3   73.096175       0.003489
# 4   10.992750       0.000243
# 5   96.471133       0.006457
# 6  143.771488       0.008937
# 7  190.405615       0.010178

# %%
whatman_paper_genome_count = pd.read_csv("../input/Badalato2017_batch_data/whatman_paper_genome_count_ml.csv")
whatman_paper_genome_count["Biomass [g/L]"] = whatman_paper_genome_count[" y"].map(lambda x:(x*dna_genome_copies/DNA_mass)*1e8 *1e3) # x [(genome copy nr) * (1e-8)/mL] * dna_genome_copies [g_DNA/(genome copy nr)] / DNA_mass [g_DNA/g_bio] = concentration [(1e-8)*g_bio/(mL)] -> concentration 1e3*1e8 [g_bio/L]
whatman_paper_biomass = whatman_paper_genome_count.drop(" y",axis=1).set_index("x")
whatman_paper_biomass.index.name="time [h]"
whatman_paper_biomass.reset_index(inplace=True)
whatman_paper_biomass
# Out:
#      time [h]  Biomass [g/L]
# 0    5.486577       0.000297
# 1   26.764879       0.000137
# 2   49.644619       0.001417
# 3   73.268967       0.004940
# 4   96.252026       0.004655
# 5  143.771488       0.006863
# 6  190.872330       0.006490

# %%
def add_dynamic_bounds(model, conc_dict,glc_eq_dict):
    """Use external concentrations to bound the uptake flux of glucose."""
    #biomass, glucose, cellobiose,cellulose = y  # expand the boundary species
    
    for key,glc_eq in glc_eq_dict.items():
        #max_import = -(2.9/(glc_eq*len(glc_eq_dict)))* conc_dict[key] / (4.4/glc_eq + conc_dict[key])
        max_import = -(5/(glc_eq*len(glc_eq_dict)))* conc_dict[key] / (0.1 + conc_dict[key])
        print(f"{key}: {max_import}")
        model.reactions.get_by_id(key).lower_bound = max_import
        
    #cellulase =  -2.9*(conc_dict["EX_cellulose_e"]/((1 + (conc_dict["EX_cellb_e"]/11))*4.4  + conc_dict["EX_cellulose_e"]))
    cellulase =  -2.9*(conc_dict["EX_cellulose_e"]/((1 + (conc_dict["EX_cellb_e"]/11))*4.4  + conc_dict["EX_cellulose_e"]))
    
    return cellulase
    
    
    
def dynamic_system(t, y,rxns,objective_dir,glc_eq_dict):
    """Calculate the time derivative of external species."""

    #biomass, glucose, cellobiose,cellulose = y  # expand the boundary species
    
    rxns_map = copy.copy(rxns)
    rxns_map.append("EX_cellulose_e")
    
    conc_dict = dict(zip(rxns_map,y))
    
    # Calculate the specific exchanges fluxes at the given external concentrations.
    with model:
        cellulase = add_dynamic_bounds(model, conc_dict,glc_eq_dict)
        feasibility = cobra.util.fix_objective_as_constraint(model)
        lex_constraints = cobra.util.add_lexicographic_constraints(model, rxns, objective_dir)
        
    # Since the calculated fluxes are specific rates, we multiply them by the
    # biomass concentration to get the bulk exchange rates.
    fluxes =lex_constraints.values
    
    i = 1 
    for key, glc_eq in glc_eq_dict.items():
        uptake = fluxes[i]
        fluxes[i] = uptake - cellulase*1/(len(glc_eq_dict)*glc_eq)
        i +=1
        
    fluxes =np.append(fluxes, cellulase)
    fluxes *= conc_dict["Growth"]

    # This implementation is **not** efficient, so I display the current
    # simulation time using a progress bar.
    if dynamic_system.pbar is not None:
        dynamic_system.pbar.update(1)
        dynamic_system.pbar.set_description('t = {:.3f}'.format(t))
    
    return fluxes

dynamic_system.pbar = None

# %% [markdown]
# ### Whatman Paper/Cotton (Cellulose)

# %%
model = cobra.io.read_sbml_model('../models/RcH10_final2.xml')
 
medium = model.medium

medium["EX_glc__D_e"]=10
model.medium = medium
#cobra.flux_analysis.parsimonious.add_pfba(model)
cobra.util.add_lp_feasibility(model)

# %% [raw]
# cellulose_glc_eq_dict =OrderedDict({
# "EX_cellb_e": 2,
# "EX_glc__D_e": 1,
# "EX_cell3_e": 3,
# "EX_cell4_e": 4,
# "EX_cell5_e": 5})
#
#
# molarmass_polysaccharide = []
#
# for rxn,glc_eq in cellulose_glc_eq_dict.items():
#     met = rxn.replace("EX_","")
#     met = met.replace("M_","")
#     formula = model.metabolites.get_by_id(met).notes["FORMULA"]
#     molarmass = molmass.Formula(formula).mass
#
#     molarmass_polysaccharide.append(molarmass/(glc_eq*len(cellulose_glc_eq_dict)))
# tot_molarmass = sum(molarmass_polysaccharide)
#
#
# polysaccharide_mass = 2.5 # g/L
#
# polysaccharide_mmol = polysaccharide_mass * 1000/tot_molarmass # mmol/L
#
# print(f"Molar mass polysaccharide:{tot_molarmass}, mmol polysaccharide: {polysaccharide_mmol}")
#
# ts = np.linspace(0, 200, 1000)  # Desired integration resolution and interval
#
# y0 = [cotton_biomass.iloc[0,1],0,0,0,0,0,polysaccharide_mmol]
#
#
# rxns = ["Growth"]
# rxns_xylo = list(cellulose_glc_eq_dict.keys())
# rxns.extend(rxns_xylo)
#
# objective_dir = ["max" for element in rxns]
#
# with tqdm() as pbar:
#     dynamic_system.pbar = pbar
#
#     sol = solve_ivp(
#         fun=dynamic_system,
#         #events=[infeasible_event],
#         t_span=(ts.min(), ts.max()),
#         y0=y0,
#         t_eval=ts,
#         #rtol=1e-6,
#         #atol=1e-8,
#         method='LSODA',
#         args = (rxns,objective_dir,cellulose_glc_eq_dict)
#     )

# %%
fig,ax = plt.subplots(1,3,figsize=(10,4))
#ax[0].plot(sol.t, sol.y.T[:, 0]*1000,label = 'Biomass [mg/L]')
ax[0].plot(sol.t, sol.y.T[:, 0],label = 'Biomass sim [g/L]')

#ax[0].set_ylim([0,600])
ax[0].set_ylim([0,2])
ax[0].legend()

ax[0].plot(cotton_biomass["time [h]"].values, cotton_biomass["Biomass [g/L]"].values,'o',label = 'Biomass exp[g/L]')

cotton_biomass

ax[1].plot(sol.t, sol.y.T[:, -1]*tot_molarmass/1000, color='g',label='Cellulose [g/L]')
#ax[1].set_title('Cellulose [g/L]',color='g')
ax[1].set_ylim([0,3])
ax[1].legend()

ax[2].plot(sol.t, sol.y.T[:, 1], color='r',label="Glucose")
ax[2].plot(sol.t, sol.y.T[:, 2], color='g',label="Cellobiose")
ax[2].plot(sol.t, sol.y.T[:, 3], color='y',label="Cellotriose")
ax[2].plot(sol.t, sol.y.T[:, 4], color='b',label="Cellotetraose")
ax[2].plot(sol.t, sol.y.T[:, 5], color='pink',label="Cellopentaose")

ax[2].set_ylim([0,1.5])

ax[2].set_title('Concentration mmol/liter')
ax[2].legend()
